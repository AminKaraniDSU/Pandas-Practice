# %% [markdown]
# # Data Sets
# [Chiporders Data Set](https://bit.ly/chiporders)
#
# [Movieusers Data Set](https://bit.ly/movieusers)
#
# [uforeports Data Set](https://bit.ly/uforeports)

# %%
import pandas as pd

# %%
user_col = ('user_id', 'age', 'gender', 'occupation', 'zip_code')
df_2 = pd.read_csv('https://bit.ly/movieusers', sep='|',header=None, index_col=0, names=user_col)
df_2
# Out:
#          age gender     occupation zip_code
# user_id
# 1         24      M     technician    85711
# 2         53      F          other    94043
# 3         23      M         writer    32067
# 4         24      M     technician    43537
# 5         33      F          other    15213
# ...      ...    ...            ...      ...
# 939       26      F        student    33319
# 940       32      M  administrator    02215
# 941       20      M        student    97229
# 942       48      F      librarian    78209
# 943       22      M        student    77841
#
# [943 rows x 4 columns]

# %% [markdown]
# #### Adding new column

# %%
ufo = pd.read_csv('https://bit.ly/uforeports')
ufo['location'] = ufo.City +', '+ ufo.State
ufo
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                  location
# 0        6/1/1930 22:00                Ithaca, NY
# 1       6/30/1930 20:00           Willingboro, NJ
# ...

# %%
ufo.rename(columns={'Colors Reported':'Colors', 'Shape Reported':'Shape'}, inplace=True)
ufo
# Out:
#                        City Colors     Shape State              Time  \
# 0                    Ithaca    NaN  TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro    NaN     OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke    NaN      OVAL    CO   2/15/1931 14:00
# 3                   Abilene    NaN      DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair    NaN     LIGHT    NY   4/18/1933 19:00
# ...                     ...    ...       ...   ...               ...
# 18236            Grant Park    NaN  TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake    NaN      DISK    IA  12/31/2000 23:00
# 18238           Eagle River    NaN       NaN    WI  12/31/2000 23:45
# 18239           Eagle River    RED     LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor    NaN      OVAL    FL  12/31/2000 23:59
#
#                        location
# 0                    Ithaca, NY
# 1               Willingboro, NJ
# 2                   Holyoke, CO
# ...

# %%
ufo_col = ['location', 'city', 'colors', 'shape', 'state', 'time']
ufo.columns = ufo_col
ufo
# Out:
#                    location city    colors shape             state  \
# 0                    Ithaca  NaN  TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro  NaN     OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke  NaN      OVAL    CO   2/15/1931 14:00
# 3                   Abilene  NaN      DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair  NaN     LIGHT    NY   4/18/1933 19:00
# ...                     ...  ...       ...   ...               ...
# 18236            Grant Park  NaN  TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake  NaN      DISK    IA  12/31/2000 23:00
# 18238           Eagle River  NaN       NaN    WI  12/31/2000 23:45
# 18239           Eagle River  RED     LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor  NaN      OVAL    FL  12/31/2000 23:59
#
#                            time
# 0                    Ithaca, NY
# 1               Willingboro, NJ
# 2                   Holyoke, CO
# ...

# %%
ufo = pd.read_csv('https://bit.ly/uforeports')
ufo.columns = ufo.columns.str.replace(' ','_').str.lower()
ufo.columns
# Out:
# Index(['city', 'colors_reported', 'shape_reported', 'state', 'time'], dtype='object')
